# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from torch import nn,optim
from torch.utils.data import Dataset, DataLoader

from generic_data import GenericDataset
from SimpleNNs import TwoNet

# %%
seed = 0
np.random.seed(seed)
torch.manual_seed(seed)

# %%
def target(x):
    return np.sin(8 * x) / (4 * np.cos(2 * x))

# %%
# define range
low = -2
high = 2

# %%
# generate test set
Xtest = np.sort(np.random.uniform(low, high, 100))
# Xtest = np.linspace(low, high, 100)
Ytest = target(Xtest)

# %%
test_dataset = GenericDataset(Xtest.reshape(-1,1), Ytest.reshape(-1,1))

# %%
subfolder = "same_base12" #"random_init"
paths = [f'./models/{subfolder}/model_{i:02d}.pt' for i in range(100)]

# %%
all_preds = []
all_labels = []

# %%
device="cuda"

# %%
test_loader = DataLoader(dataset=test_dataset,batch_size=64,shuffle=False)

# %%
num_models = len(paths)
cnt = 1

for path in paths:
    model = torch.load(path)
    model.to(device)
    model.eval()
    
    preds = []
    labels = []
    
    for batch_vec, batch_labels in iter(test_loader):
        batch_vec = batch_vec.to(device)
        batch_outputs = model(batch_vec)
        batch_preds = batch_outputs.cpu().detach().numpy()
        batch_labels = batch_labels.numpy()
        preds.append(batch_preds)
        labels.append(batch_labels)
    
    preds = np.concatenate(preds).flatten()
    labels = np.concatenate(labels).flatten()
    
    regression_error = np.square(np.subtract(preds, labels)).mean()
    
    print(path)
    print(regression_error)
    print(f'Regression Error {regression_error}. Model {cnt}/{num_models}')
    
    all_preds.append(preds)
    all_labels.append(labels)
    cnt += 1
    
all_preds = np.vstack(all_preds)
all_labels = np.vstack(all_labels)
# Out:
# ./models/same_base12/model_00.pt
# 0.08195612695829041
# Regression Error 0.08195612695829041. Model 1/100
# ./models/same_base12/model_01.pt
# 0.08208454962913826
# Regression Error 0.08208454962913826. Model 2/100
# ./models/same_base12/model_02.pt
# 0.08222158320791484
# Regression Error 0.08222158320791484. Model 3/100
# ./models/same_base12/model_03.pt
# 0.08221709999182086
# Regression Error 0.08221709999182086. Model 4/100
# ./models/same_base12/model_04.pt
# 0.08233504675879433
# Regression Error 0.08233504675879433. Model 5/100
# ./models/same_base12/model_05.pt
# 0.0821700896568579
# Regression Error 0.0821700896568579. Model 6/100
# ./models/same_base12/model_06.pt
# 0.08233227316384495
# Regression Error 0.08233227316384495. Model 7/100
# ./models/same_base12/model_07.pt
# 0.08162040332463141
# Regression Error 0.08162040332463141. Model 8/100
# ./models/same_base12/model_08.pt
# 0.08171002026031793
# Regression Error 0.08171002026031793. Model 9/100
# ./models/same_base12/model_09.pt
# 0.0820973085949795
# Regression Error 0.0820973085949795. Model 10/100
# ./models/same_base12/model_10.pt
# 0.08211878644924957
# Regression Error 0.08211878644924957. Model 11/100
# ./models/same_base12/model_11.pt
# 0.08244373123813226
# Regression Error 0.08244373123813226. Model 12/100
# ./models/same_base12/model_12.pt
# 0.08192692822597136
# Regression Error 0.08192692822597136. Model 13/100
# ./models/same_base12/model_13.pt
# 0.08248339928213792
# Regression Error 0.08248339928213792. Model 14/100
# ./models/same_base12/model_14.pt
# 0.08274947340300795
# Regression Error 0.08274947340300795. Model 15/100
# ./models/same_base12/model_15.pt
# 0.0824335684936991
# Regression Error 0.0824335684936991. Model 16/100
# ./models/same_base12/model_16.pt
# 0.08150268697208682
# Regression Error 0.08150268697208682. Model 17/100
# ./models/same_base12/model_17.pt
# 0.08161423932076704
# Regression Error 0.08161423932076704. Model 18/100
# ./models/same_base12/model_18.pt
# 0.0828373431237535
# Regression Error 0.0828373431237535. Model 19/100
# ./models/same_base12/model_19.pt
# 0.08246039829359071
# Regression Error 0.08246039829359071. Model 20/100
# ./models/same_base12/model_20.pt
# 0.08224983522958061
# Regression Error 0.08224983522958061. Model 21/100
# ./models/same_base12/model_21.pt
# 0.08244658853477516
# Regression Error 0.08244658853477516. Model 22/100
# ./models/same_base12/model_22.pt
# 0.08189029088137997
# Regression Error 0.08189029088137997. Model 23/100
# ./models/same_base12/model_23.pt
# 0.08188837006044616
# Regression Error 0.08188837006044616. Model 24/100
# ./models/same_base12/model_24.pt
# 0.08146386189129794
# Regression Error 0.08146386189129794. Model 25/100
# ./models/same_base12/model_25.pt
# 0.0818754078575039
# Regression Error 0.0818754078575039. Model 26/100
# ./models/same_base12/model_26.pt
# 0.08201459730638636
# Regression Error 0.08201459730638636. Model 27/100
# ./models/same_base12/model_27.pt
# 0.08194851032239552
# Regression Error 0.08194851032239552. Model 28/100
# ./models/same_base12/model_28.pt
# 0.08214713908035097
# Regression Error 0.08214713908035097. Model 29/100
# ./models/same_base12/model_29.pt
# 0.08224197759064511
# Regression Error 0.08224197759064511. Model 30/100
# ./models/same_base12/model_30.pt
# 0.08184557127476326
# Regression Error 0.08184557127476326. Model 31/100
# ./models/same_base12/model_31.pt
# 0.08224443887130482
# Regression Error 0.08224443887130482. Model 32/100
# ./models/same_base12/model_32.pt
# 0.0819884021357356
# Regression Error 0.0819884021357356. Model 33/100
# ./models/same_base12/model_33.pt
# 0.08231702895553723
# Regression Error 0.08231702895553723. Model 34/100
# ./models/same_base12/model_34.pt
# 0.0821251741769998
# Regression Error 0.0821251741769998. Model 35/100
# ./models/same_base12/model_35.pt
# 0.08179987180298762
# Regression Error 0.08179987180298762. Model 36/100
# ./models/same_base12/model_36.pt
# 0.08182807364054252
# Regression Error 0.08182807364054252. Model 37/100
# ./models/same_base12/model_37.pt
# 0.08149510964042062
# Regression Error 0.08149510964042062. Model 38/100
# ./models/same_base12/model_38.pt
# 0.08242847067243274
# Regression Error 0.08242847067243274. Model 39/100
# ./models/same_base12/model_39.pt
# 0.08159855883468968
# Regression Error 0.08159855883468968. Model 40/100
# ./models/same_base12/model_40.pt
# 0.08229519476397035
# Regression Error 0.08229519476397035. Model 41/100
# ./models/same_base12/model_41.pt
# 0.08175697500950807
# Regression Error 0.08175697500950807. Model 42/100
# ./models/same_base12/model_42.pt
# 0.08215909003875048
# Regression Error 0.08215909003875048. Model 43/100
# ./models/same_base12/model_43.pt
# 0.08198641426326912
# Regression Error 0.08198641426326912. Model 44/100
# ./models/same_base12/model_44.pt
# 0.08253876064704878
# Regression Error 0.08253876064704878. Model 45/100
# ./models/same_base12/model_45.pt
# 0.08161401641563656
# Regression Error 0.08161401641563656. Model 46/100
# ./models/same_base12/model_46.pt
# 0.08220483916015628
# Regression Error 0.08220483916015628. Model 47/100
# ./models/same_base12/model_47.pt
# 0.08212016530506426
# Regression Error 0.08212016530506426. Model 48/100
# ./models/same_base12/model_48.pt
# 0.08152312265732613
# Regression Error 0.08152312265732613. Model 49/100
# ./models/same_base12/model_49.pt
# 0.08166435402973915
# Regression Error 0.08166435402973915. Model 50/100
# ./models/same_base12/model_50.pt
# 0.08207159999024105
# Regression Error 0.08207159999024105. Model 51/100
# ./models/same_base12/model_51.pt
# 0.08237111297031471
# Regression Error 0.08237111297031471. Model 52/100
# ./models/same_base12/model_52.pt
# 0.0824987842441588
# Regression Error 0.0824987842441588. Model 53/100
# ./models/same_base12/model_53.pt
# 0.0824160872103122
# Regression Error 0.0824160872103122. Model 54/100
# ./models/same_base12/model_54.pt
# 0.08251410242822997
# Regression Error 0.08251410242822997. Model 55/100
# ./models/same_base12/model_55.pt
# 0.0826496299748464
# Regression Error 0.0826496299748464. Model 56/100
# ./models/same_base12/model_56.pt
# 0.08181445096222145
# Regression Error 0.08181445096222145. Model 57/100
# ./models/same_base12/model_57.pt
# 0.08164278654164653
# Regression Error 0.08164278654164653. Model 58/100
# ./models/same_base12/model_58.pt
# 0.08165081447357116
# Regression Error 0.08165081447357116. Model 59/100
# ./models/same_base12/model_59.pt
# 0.0818789557672135
# Regression Error 0.0818789557672135. Model 60/100
# ./models/same_base12/model_60.pt
# 0.08277460395247342
# Regression Error 0.08277460395247342. Model 61/100
# ./models/same_base12/model_61.pt
# 0.08146369060599494
# Regression Error 0.08146369060599494. Model 62/100
# ./models/same_base12/model_62.pt
# 0.08240891230689927
# Regression Error 0.08240891230689927. Model 63/100
# ./models/same_base12/model_63.pt
# 0.08212465050334661
# Regression Error 0.08212465050334661. Model 64/100
# ./models/same_base12/model_64.pt
# 0.08174941889041692
# Regression Error 0.08174941889041692. Model 65/100
# ./models/same_base12/model_65.pt
# 0.08182374603132399
# Regression Error 0.08182374603132399. Model 66/100
# ./models/same_base12/model_66.pt
# 0.08162791353621855
# Regression Error 0.08162791353621855. Model 67/100
# ./models/same_base12/model_67.pt
# 0.08214624192826142
# Regression Error 0.08214624192826142. Model 68/100
# ./models/same_base12/model_68.pt
# 0.08176924352689272
# Regression Error 0.08176924352689272. Model 69/100
# ./models/same_base12/model_69.pt
# 0.08260307636520943
# Regression Error 0.08260307636520943. Model 70/100
# ./models/same_base12/model_70.pt
# 0.08182630374730439
# Regression Error 0.08182630374730439. Model 71/100
# ./models/same_base12/model_71.pt
# 0.08260846491489254
# Regression Error 0.08260846491489254. Model 72/100
# ./models/same_base12/model_72.pt
# 0.08208381449854468
# Regression Error 0.08208381449854468. Model 73/100
# ./models/same_base12/model_73.pt
# 0.0818744927254039
# Regression Error 0.0818744927254039. Model 74/100
# ./models/same_base12/model_74.pt
# 0.08208073624739269
# Regression Error 0.08208073624739269. Model 75/100
# ./models/same_base12/model_75.pt
# 0.08221062578312825
# Regression Error 0.08221062578312825. Model 76/100
# ./models/same_base12/model_76.pt
# 0.08237737144919359
# Regression Error 0.08237737144919359. Model 77/100
# ./models/same_base12/model_77.pt
# 0.08185515021074191
# Regression Error 0.08185515021074191. Model 78/100
# ./models/same_base12/model_78.pt
# 0.08216587625364209
# Regression Error 0.08216587625364209. Model 79/100
# ./models/same_base12/model_79.pt
# 0.08129627000983351
# Regression Error 0.08129627000983351. Model 80/100
# ./models/same_base12/model_80.pt
# 0.08252656064601066
# Regression Error 0.08252656064601066. Model 81/100
# ./models/same_base12/model_81.pt
# 0.08232983203403794
# Regression Error 0.08232983203403794. Model 82/100
# ./models/same_base12/model_82.pt
# 0.08256571671421631
# Regression Error 0.08256571671421631. Model 83/100
# ./models/same_base12/model_83.pt
# 0.08203734311520329
# Regression Error 0.08203734311520329. Model 84/100
# ./models/same_base12/model_84.pt
# 0.082482286711952
# Regression Error 0.082482286711952. Model 85/100
# ./models/same_base12/model_85.pt
# 0.0820598861820021
# Regression Error 0.0820598861820021. Model 86/100
# ./models/same_base12/model_86.pt
# 0.08263542495529949
# Regression Error 0.08263542495529949. Model 87/100
# ./models/same_base12/model_87.pt
# 0.08199977967937601
# Regression Error 0.08199977967937601. Model 88/100
# ./models/same_base12/model_88.pt
# 0.08281109375727484
# Regression Error 0.08281109375727484. Model 89/100
# ./models/same_base12/model_89.pt
# 0.08217364583250829
# Regression Error 0.08217364583250829. Model 90/100
# ./models/same_base12/model_90.pt
# 0.08226792805050458
# Regression Error 0.08226792805050458. Model 91/100
# ./models/same_base12/model_91.pt
# 0.08226101975049824
# Regression Error 0.08226101975049824. Model 92/100
# ./models/same_base12/model_92.pt
# 0.08216757134627985
# Regression Error 0.08216757134627985. Model 93/100
# ./models/same_base12/model_93.pt
# 0.08246193556385702
# Regression Error 0.08246193556385702. Model 94/100
# ./models/same_base12/model_94.pt
# 0.08269583498179948
# Regression Error 0.08269583498179948. Model 95/100
# ./models/same_base12/model_95.pt
# 0.08218399817236773
# Regression Error 0.08218399817236773. Model 96/100
# ./models/same_base12/model_96.pt
# 0.08203540977099079
# Regression Error 0.08203540977099079. Model 97/100
# ./models/same_base12/model_97.pt
# 0.08223868418655618
# Regression Error 0.08223868418655618. Model 98/100
# ./models/same_base12/model_98.pt
# 0.0820636878440632
# Regression Error 0.0820636878440632. Model 99/100
# ./models/same_base12/model_99.pt
# 0.08228316042267622
# Regression Error 0.08228316042267622. Model 100/100

# %%
all_preds
# Out:
# array([[ 0.00430103,  0.01172724,  0.01242155, ..., -0.0127975 ,
#         -0.01193912, -0.00742658],
#        [ 0.00248183,  0.01036888,  0.01110628, ..., -0.01218976,
#         -0.01139218, -0.00718968],
#        [ 0.00341124,  0.01125633,  0.0119898 , ..., -0.01188572,
#         -0.011086  , -0.00688533],
#        ...,
#        [ 0.00124948,  0.0093052 ,  0.01005837, ..., -0.0143688 ,
#         -0.01353837, -0.0091764 ],
#        [ 0.00477749,  0.01225801,  0.0129574 , ..., -0.01321751,
#         -0.01236554, -0.00789048],
#        [ 0.00305283,  0.01073483,  0.01145305, ..., -0.01336487,
#         -0.01250955, -0.00801688]])

# %%
all_labels
# Out:
# array([[-0.05182882,  0.10016105,  0.11228079, ..., -0.1394703 ,
#         -0.12362103, -0.02770573],
#        [-0.05182882,  0.10016105,  0.11228079, ..., -0.1394703 ,
#         -0.12362103, -0.02770573],
#        [-0.05182882,  0.10016105,  0.11228079, ..., -0.1394703 ,
#         -0.12362103, -0.02770573],
#        ...,
#        [-0.05182882,  0.10016105,  0.11228079, ..., -0.1394703 ,
#         -0.12362103, -0.02770573],
#        [-0.05182882,  0.10016105,  0.11228079, ..., -0.1394703 ,
#         -0.12362103, -0.02770573],
#        [-0.05182882,  0.10016105,  0.11228079, ..., -0.1394703 ,
#         -0.12362103, -0.02770573]])

# %%
np.save(f'./models/{subfolder}/xs', Xtest)
np.save(f'./models/{subfolder}/predictions',all_preds)
np.save(f'./models/{subfolder}/true_labels',all_labels[0])
